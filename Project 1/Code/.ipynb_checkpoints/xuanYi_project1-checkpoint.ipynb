# %% [markdown]
# # SC2001 Project 1 (Lab Group A33, Group 1)
# ## Integration of Mergesort & Insertion Sort

# %% [markdown]
# > In Mergesort, when the sizes of subarrays are small, the overhead of many recursive calls makes the algorithm inefficient. Therefore, in real use, we often combine Mergesort with Insertion Sort to come up with a hybrid sorting algorithm for better efficiency. The idea is to set a small integer S as a threshold for the size of subarrays. <br><br>
# > Once the size of a subarray in a recursive call of Mergesort is less than or equal to S, the algorithm will switch to Insertion Sort, which is efficient for small-sized input.

# %%
# Imports
import time
import copy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Setting seed to ensure that our data does not change in the future.
np.random.seed(10)

# %% [markdown]
# ### a) Algorithm Implementation

# %% [markdown]
# > Implement the above hybrid algorithm.

# %%
# Create an Object to store the Number of Key Comparisons in our Sorting Methods
class KeyComparisons:
    def __init__(self):
        self.numKeyComparisons = 0

    def isALargerThanB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a > b

    def isALessThanB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a < b

    def isAEqualB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a == b

    def incrementKeyComparisons(self, incrementValue):
        self.numKeyComparisons += incrementValue

    def resetKeyComparisons(self):
        self.numKeyComparisons = 0
        
    def returnKeyComparisons(self):
        return self.numKeyComparisons
        

# Declaring a Constant for Fixed Threshold Value
def FIXED_THRESHOLD_VALUE():
    return 10

# %% [markdown]
# ### Insertion Sort

# %%
def insertionSort(arr, comparisonsObject):
    
    # Traverse for each element from index 1 to end of list. First element can be ignored.
    for i in range(1, len(arr)):
        key = arr[i] # Pick out the element at the i-th position
        j = i-1 # j will be the running index for all the elements before elem
        
        while j >= 0 and comparisonsObject.isALessThanB(key, arr[j]): # While it hasn't reached the first element and the key is smaller than the previous elements, we will shift the j-th element to the j+1-th position
            # comparisonsObject.incrementKeyComparisons(1)
            arr[j+1] = arr[j]
            j -= 1
        # comparisonsObject.incrementKeyComparisons(1)
        
        
        arr[j+1] = key # If we reach an element that is smaller than the key or the start of the list (j=-1), we will insert the key to the right of that element or at index 0 if it reached start of list.
    return arr

# %% [markdown]
# ### Hybrid Sort

# %%
# Merge function which will be used in the hybrid sort when merge sort is chosen over insertion sort.

def merge(arr1, arr2, comparisonsObject):
    # initialise indices for each array
    i = 0
    j = 0
    
    # initialise final sorted array
    sorted_arr = []
    
    # While both halves are not empty, we compare the 1st elements of the 2 lists
    while i != len(arr1) and j != len(arr2):
        # Keeping track of the Number of Comparisons
        # comparisonsObject.incrementKeyComparisons(1)
        # if first element of 1st list is smaller, 1st element of first half joins the end of the merged list
        if comparisonsObject.isALessThanB(arr1[i], arr2[j]):
            sorted_arr.append(arr1[i])
            i += 1
        # else if 1st element of 2nd list is smaller, move the 1st element of 2nd half to the end of the merged list
        elif arr2[j] < arr1[i]:
            sorted_arr.append(arr2[j])
            j += 1
        # else if they are equal, move both the 1st element of the first list and the second list to the merged list
        else:
            sorted_arr.append(arr1[i])
            sorted_arr.append(arr2[j])
            i += 1
            j += 1
    # if first list still has elements, copy all the elements in the first list to the merged list
    while i != len(arr1):
        sorted_arr.append(arr1[i])
        i += 1
    # if second list still has elements, copy all the elements in the second list to the merged list
    while j != len(arr2):
        sorted_arr.append(arr2[j])
        j += 1
    return sorted_arr

# %%
def mergeSort(arr, comparisonsObject, criterion):
    # Use the middle element to divide the array into two halves
    m = len(arr)//2

    # Base case. Array has 1 element.
    if len(arr) <= 1:
        return arr
    
    # Recursive step
    if len(arr) > criterion:
        # Sort first half recursively
        arr[:m] = mergeSort(arr[:m], comparisonsObject, criterion)
        # Sort second half recursively
        arr[m:] = mergeSort(arr[m:], comparisonsObject, criterion)
    arr = merge(arr[:m], arr[m:], comparisonsObject)
    
    return arr

# %%
# Hybrid Sort takes in parameters of an array and array size limit S.
# If array size is <= S, insertion sort will be used 
# If array size is > S , merge sort will be used instead

def hybridSort(arr,S, comparisonsObject):
    # Base case. Array has 1 element.
    if len(arr) <= 1:
        return arr
    
    # Recursive step
    
    # Merge Sort 
    if len(arr) > S:
        # Use the middle element to divide the array into two halves
        m = len(arr)//2
        # Sort first half recursively
        arr[:m] = hybridSort(arr[:m],S, comparisonsObject)
        # Sort second half recursively
        arr[m:] = hybridSort(arr[m:], S, comparisonsObject)
        arr = merge(arr[:m], arr[m:], comparisonsObject)
        return arr
    
    # Insertion Sort
    else:
        arr = insertionSort(arr, comparisonsObject)
        return arr

# %% [markdown]
# ### Testing the sorting algorithms

# %%
arr = [4,2,10,100,3,59,43,-1,-8,0,7,12,11,3,3,3]
comparisonsObject = KeyComparisons()   

print(hybridSort(arr, 3, comparisonsObject))
# Out:
# [-8, -1, 0, 2, 3, 3, 3, 3, 4, 7, 10, 11, 12, 43, 59, 100]

# %% [markdown]
# ## b) Generate input data

# %% [markdown]
# > Generate arrays of increasing sizes, in a range from
# 1,000 to 10 million. For each of the sizes, generate a random dataset of integers in the range of [1, …, x], where x is the largest number you allow for your datasets.

# %%
# Generate the required sizes of the arrays programatically from the range of 1,000 to 10 million.

inputDataSizes = []

for i in range(10):
    inputDataSizes.append((i+1) * 1000)
    inputDataSizes.append((i+1) * 10000)
    inputDataSizes.append((i+1) * 100000)
    inputDataSizes.append((i+1) * 1000000)

# Remove duplicates and sort the input data sizes
inputDataSizes = sorted(set(inputDataSizes))
print(inputDataSizes)
# Out:
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000, 10000000]

# %%
# List of List of data
inputData = []

# Iterate through the data sizes array
for s in inputDataSizes:
    # For each datasize, we generate a random data array of size (s), each array will contain random integers from 1 to s.
    data = np.random.randint(1,s+1,size = s)
    inputData.append(data)
    
# Checking for the array of size 1000 that the generation was done correctly.    
for i in range(len(inputData)):
    print("Array Size: ", len(inputData[i]))
    print("Min of this array:" , min(inputData[i]))
    print("Max of this array:" , max(inputData[i]))
    print()
# Out:
# Array Size:  1000
# Min of this array: 1
# Max of this array: 999
#
# Array Size:  2000
# Min of this array: 3
# Max of this array: 1998
#
# Array Size:  3000
# Min of this array: 2
# Max of this array: 2998
#
# Array Size:  4000
# Min of this array: 1
# Max of this array: 4000
#
# Array Size:  5000
# Min of this array: 3
# Max of this array: 4999
#
# Array Size:  6000
# Min of this array: 1
# Max of this array: 5999
#
# Array Size:  7000
# Min of this array: 1
# Max of this array: 6999
#
# Array Size:  8000
# Min of this array: 2
# Max of this array: 7999
#
# Array Size:  9000
# Min of this array: 4
# Max of this array: 9000
#
# Array Size:  10000
# Min of this array: 2
# Max of this array: 10000
#
# Array Size:  20000
# Min of this array: 1
# Max of this array: 19999
#
# Array Size:  30000
# Min of this array: 1
# Max of this array: 30000
#
# Array Size:  40000
# Min of this array: 1
# Max of this array: 39998
#
# Array Size:  50000
# Min of this array: 3
# Max of this array: 50000
#
# Array Size:  60000
# Min of this array: 1
# Max of this array: 59999
#
# Array Size:  70000
# Min of this array: 1
# Max of this array: 70000
#
# Array Size:  80000
# Min of this array: 2
# Max of this array: 80000
#
# Array Size:  90000
# Min of this array: 1
# Max of this array: 90000
#
# Array Size:  100000
# Min of this array: 1
# Max of this array: 100000
#
# Array Size:  200000
# Min of this array: 3
# Max of this array: 199997
#
# Array Size:  300000
# Min of this array: 2
# Max of this array: 299999
#
# Array Size:  400000
# Min of this array: 2
# Max of this array: 400000
#
# Array Size:  500000
# Min of this array: 2
# Max of this array: 499997
#
# Array Size:  600000
# Min of this array: 1
# Max of this array: 600000
#
# Array Size:  700000
# Min of this array: 5
# Max of this array: 700000
#
# Array Size:  800000
# Min of this array: 2
# Max of this array: 799999
#
# Array Size:  900000
# Min of this array: 2
# Max of this array: 900000
#
# Array Size:  1000000
# Min of this array: 2
# Max of this array: 1000000
#
# Array Size:  2000000
# Min of this array: 1
# Max of this array: 2000000
#
# Array Size:  3000000
# Min of this array: 1
# Max of this array: 3000000
#
# Array Size:  4000000
# Min of this array: 1
# Max of this array: 3999999
#
# Array Size:  5000000
# Min of this array: 1
# Max of this array: 5000000
#
# Array Size:  6000000
# Min of this array: 1
# Max of this array: 5999998
#
# Array Size:  7000000
# Min of this array: 3
# Max of this array: 7000000
#
# Array Size:  8000000
# Min of this array: 1
# Max of this array: 8000000
#
# Array Size:  9000000
# Min of this array: 2
# Max of this array: 8999997
#
# Array Size:  10000000
# Min of this array: 1
# Max of this array: 9999998

# %% [markdown]
# ### c) Analyse Time Complexity
#
# #### Run your program of the hybrid algorithm on the datasets generated in Step (b). Record the number of key comparisons performed in each case.

# %% [markdown]
# c)i) With the value of S fixed, plot the number of key comparisons over different sizes of the input list n. Compare your empirical results with your theoretical analysis of the time complexity.

# %%
# Fix the Threshold Value S
thresholdValueS = FIXED_THRESHOLD_VALUE()

# Create Arrays to store X and Y Coordinates
fixedThresholdXCoordinates = []
fixedThresholdYCoordinates = []
fixedThresholdTimeCoordinates = []

# Run Hybrid Sort over each Individual Array
for array in inputData:
    copyOfArray = copy.deepcopy(array)
    arrayLength = len(copyOfArray)
    print("Current Array Size: {}".format(arrayLength))
    
    # Create Timestamps to track the time taken for the Hybrid Sort to sort this Array
    startTimestamp = time.time()
    hybridSort(copyOfArray, thresholdValueS, comparisonsObject)
    endingTimestamp = time.time()

    # Record the KeyComparisons (Y) and Different Threshold Values S(X)
    numKeyComparisons1 = comparisonsObject.returnKeyComparisons()
    fixedThresholdXCoordinates.append(arrayLength)
    fixedThresholdYCoordinates.append(numKeyComparisons1)
    fixedThresholdTimeCoordinates.append(endingTimestamp - startTimestamp)

    # Print Time Taken & Num Key Comparisons
    print("Time Elapsed for Hybrid Sort: {0:.4f} seconds".format(endingTimestamp - startTimestamp))
    print("Number of Key Comparisons: {}".format(numKeyComparisons1))
    
    # Reset the Number of Key Comparisons for Next Array
    comparisonsObject.resetKeyComparisons()
# Out:
# Current Array Size: 1000
# Time Elapsed for Hybrid Sort: 0.0041 seconds
# Number of Key Comparisons: 8772
# Current Array Size: 2000
# Time Elapsed for Hybrid Sort: 0.0098 seconds
# Number of Key Comparisons: 19517
# Current Array Size: 3000
# Time Elapsed for Hybrid Sort: 0.0150 seconds
# Number of Key Comparisons: 30386
# Current Array Size: 4000
# Time Elapsed for Hybrid Sort: 0.0197 seconds
# Number of Key Comparisons: 43080
# Current Array Size: 5000
# Time Elapsed for Hybrid Sort: 0.0250 seconds
# Number of Key Comparisons: 56566
# Current Array Size: 6000
# Time Elapsed for Hybrid Sort: 0.0316 seconds
# Number of Key Comparisons: 66799
# Current Array Size: 7000
# Time Elapsed for Hybrid Sort: 0.0369 seconds
# Number of Key Comparisons: 80063
# Current Array Size: 8000
# Time Elapsed for Hybrid Sort: 0.0427 seconds
# Number of Key Comparisons: 94045
# Current Array Size: 9000
# Time Elapsed for Hybrid Sort: 0.0495 seconds
# Number of Key Comparisons: 108492
# Current Array Size: 10000
# Time Elapsed for Hybrid Sort: 0.0550 seconds
# Number of Key Comparisons: 123169
# Current Array Size: 20000
# Time Elapsed for Hybrid Sort: 0.1207 seconds
# Number of Key Comparisons: 266341
# Current Array Size: 30000
# Time Elapsed for Hybrid Sort: 0.1891 seconds
# Number of Key Comparisons: 407826
# Current Array Size: 40000
# Time Elapsed for Hybrid Sort: 0.2584 seconds
# Number of Key Comparisons: 573335
# Current Array Size: 50000
# Time Elapsed for Hybrid Sort: 0.3346 seconds
# Number of Key Comparisons: 710157
# Current Array Size: 60000
# Time Elapsed for Hybrid Sort: 0.4079 seconds
# Number of Key Comparisons: 875986
# Current Array Size: 70000
# Time Elapsed for Hybrid Sort: 0.4788 seconds
# Number of Key Comparisons: 1048665
# Current Array Size: 80000
# Time Elapsed for Hybrid Sort: 0.5557 seconds
# Number of Key Comparisons: 1226537
# Current Array Size: 90000
# Time Elapsed for Hybrid Sort: 0.6413 seconds
# Number of Key Comparisons: 1350019
# Current Array Size: 100000
# Time Elapsed for Hybrid Sort: 0.7182 seconds
# Number of Key Comparisons: 1520035
# Current Array Size: 200000
# Time Elapsed for Hybrid Sort: 1.5381 seconds
# Number of Key Comparisons: 3240403
# Current Array Size: 300000
# Time Elapsed for Hybrid Sort: 2.3520 seconds
# Number of Key Comparisons: 5145407
# Current Array Size: 400000
# Time Elapsed for Hybrid Sort: 3.2460 seconds
# Number of Key Comparisons: 6880519
# Current Array Size: 500000
# Time Elapsed for Hybrid Sort: 4.0881 seconds
# Number of Key Comparisons: 8847281
# Current Array Size: 600000
# Time Elapsed for Hybrid Sort: 4.9562 seconds
# Number of Key Comparisons: 10889219
# Current Array Size: 700000
# Time Elapsed for Hybrid Sort: 5.8968 seconds
# Number of Key Comparisons: 12682190
# Current Array Size: 800000
# Time Elapsed for Hybrid Sort: 6.8040 seconds
# Number of Key Comparisons: 14560124
# Current Array Size: 900000
# Time Elapsed for Hybrid Sort: 7.7004 seconds
# Number of Key Comparisons: 16607382
# Current Array Size: 1000000
# Time Elapsed for Hybrid Sort: 8.5919 seconds
# Number of Key Comparisons: 18695387
# Current Array Size: 2000000
# Time Elapsed for Hybrid Sort: 18.1763 seconds
# Number of Key Comparisons: 39388902
# Current Array Size: 3000000
# Time Elapsed for Hybrid Sort: 28.5709 seconds
# Number of Key Comparisons: 60227063
# Current Array Size: 4000000
# Time Elapsed for Hybrid Sort: 38.5309 seconds
# Number of Key Comparisons: 82783726
# Current Array Size: 5000000
# Time Elapsed for Hybrid Sort: 48.5605 seconds
# Number of Key Comparisons: 106315210
# Current Array Size: 6000000
# Time Elapsed for Hybrid Sort: 59.8020 seconds
# Number of Key Comparisons: 126456082
# Current Array Size: 7000000
# Time Elapsed for Hybrid Sort: 69.9760 seconds
# Number of Key Comparisons: 149754185
# Current Array Size: 8000000
# Time Elapsed for Hybrid Sort: 80.4016 seconds
# Number of Key Comparisons: 173553453
# Current Array Size: 9000000
# Time Elapsed for Hybrid Sort: 91.3452 seconds
# Number of Key Comparisons: 197846854
# Current Array Size: 10000000
# Time Elapsed for Hybrid Sort: 102.0321 seconds
# Number of Key Comparisons: 222643204

# %%
## Plot the Graph using Matplotlib
# Plot the Points
plt.plot(fixedThresholdXCoordinates, fixedThresholdYCoordinates)

# Naming the Axes
plt.xlabel("Input List Size N")
plt.ylabel("Number of Key Comparisons")
plt.title("Graph of number of Key Comparisons against different Input List Sizes N")
# Out:
# Text(0.5, 1.0, 'Graph of number of Key Comparisons against different Input List Sizes N')

# %%
## Plot the Graph using Matplotlib
# Plot the Points
plt.plot(fixedThresholdXCoordinates, fixedThresholdTimeCoordinates)

# Naming the Axes
plt.xlabel("Input List Size N")
plt.ylabel("Time / Seconds")
plt.title("Graph of Time against different Input List Sizes N")
# Out:
# Text(0.5, 1.0, 'Graph of Time against different Input List Sizes N')

# %% [markdown]
# #### Compare Empirical Results with Theoretical Analysis for Time Complexity

# %% [markdown]
# - For Insertion Sort, there will be (n-1) iterations in the outer loop due to selecting an element from the unsorted subarray which is to be placed in the sorted subarray. Thereafter, in the inner loop, there will be some number of key comparisons for the ith iteration, depending on how the array is initially like:
#     - Best Case: In ith iteration, there will only be 1 key comparisons. Thus, there is a total of (n-1) key comparisons.
#     - Worst Case: In ith iteration, there will be i key comparisons. Thus, there will be a total of n(n-1)/2 key comparisons.
#     - Average Case: In ith iteration, there might be 1 - i key comparisons, each with 1/i probability of occuring. Hence, the average number of comparisons is 1/i * (1+2+...+i). Thus, for i iterations, there will be roughly (n-1)(n+2)/4 key comparisons, corresponding to roughly n^2 comparisons.
# ---
#
# - For Merge Sort, every key comparison between 2 sublists will move at least 1 element into the merged list. But for the last key comparison, at least 2 elements will be moved into the merged list.
#     - Best Case: Only elements from 1 sublist is placed into the merged list each time. Thus, it would require n/2 comparisons.
#     - Worst Case: Thus, merging 2 sublists of total size n would require n - 1 key comparisons.
#     - However, since the original list will be split lg(n) times. The total number of key comparisons in the best and worst case is n * lg(n).
# ---
#
# - For our implementation of Hybrid Sort, Merge Sort will be used to split the array if the array size is extremely large or when the threshold value S is extremely small. Insertion Sort will be used to sort the array when the array size is extremely small or when the threshold value outweighs the array size.
# - As the input list size N increases, the likelihood of hybrid sort using merge sort to break the input list into smaller and more manageable subarrays increases, assuming that the threshold value S is constant or increasing at a rate slower than that of the increase in N.
# - Hence, this means that the number of key comparisons will increase as N increases, at a linear rate as there won't be lg(n) splits of the original lists due to insertion sort taking over whenever the array size is considered "small" enough, that is smaller than threshold S.

# %% [markdown]
# c)ii) With the value of N fixed, plot the number of key comparisons over different sizes of the threshold value S. Compare your empirical results with your theoretical analysis of the time complexity.

# %%
def determineOptimalThreshold(initialThreshold, selectedArray, potentialThresholdValueArray, potentialThresholdTimesArray, fixedArraySizeXCoordinates, fixedArraySizeYCoordinates, inputData):
    # Array to store the Time Elapsed for each Threshold Value
    thresholdArray = []

    # Run Hybrid Sort after changing threshold value
    numThresholdValues = len(inputData)
    thresholdValueS = initialThreshold

    for i in range(numThresholdValues):
        # Create a Copy of Array
        copiedArray = copy.deepcopy(selectedArray)
        # Increment to change the thresholdValueS
        thresholdValueS += 5
        print("Current Threshold Value: {}".format(thresholdValueS))
        
        # Track the Time Elapsed for Hybrid Sort
        start = time.time()
        hybridSort(copiedArray, thresholdValueS, comparisonsObject)
        end = time.time()

        # Record the KeyComparisons (Y) and Different Threshold Values S(X)
        numKeyComparisons2 = comparisonsObject.returnKeyComparisons()
        fixedArraySizeXCoordinates.append(thresholdValueS)
        fixedArraySizeYCoordinates.append(numKeyComparisons2)
        
        # Show Time Elapsed & Num Key Comparisons
        timeElapsed1 = end - start
        thresholdArray.append(timeElapsed1)
        print("Time Elapsed: {0:.4f} seconds".format(timeElapsed1))
        print("Number of Key Comparisons: {}".format(numKeyComparisons2))
        comparisonsObject.resetKeyComparisons()

    # Determine the Optimal Threshold
    minTimeElapsed1 = min(thresholdArray)
    indexOfOptimalThreshold = thresholdArray.index(minTimeElapsed1)
    optimalThreshold = initialThreshold + (indexOfOptimalThreshold+1)*10
    
    # Append to List and Print Optimal Results
    potentialThresholdTimesArray.append(minTimeElapsed1)
    potentialThresholdValueArray.append(optimalThreshold)
    print("Optimal Threshold: {}".format(optimalThreshold))
    print("Time Taken for Optimal Threshold: {0:.4f}".format(minTimeElapsed1))

# Choose an Array to fix the Array Size
selectedArray = inputData[4]
# selectedArray = np.random.randint(1,300+1,size = 300)
print("This is Array Length: {}".format(len(selectedArray)))
# Array to store the list of potential optimal threshold values and their minimum times
testArray1 = []
testArray2 = []

# Create Arrays to store X and Y Coordinates
fixedArraySizeXCoordinates = []
fixedArraySizeYCoordinates = []

determineOptimalThreshold(0, selectedArray, testArray1, testArray2, fixedArraySizeXCoordinates, fixedArraySizeYCoordinates, inputData)
# Out:
# This is Array Length: 5000
# Current Threshold Value: 5
# Time Elapsed: 0.0266 seconds
# Number of Key Comparisons: 53772
# Current Threshold Value: 10
# Time Elapsed: 0.0250 seconds
# Number of Key Comparisons: 56566
# Current Threshold Value: 15
# Time Elapsed: 0.0252 seconds
# Number of Key Comparisons: 56566
# Current Threshold Value: 20
# Time Elapsed: 0.0264 seconds
# Number of Key Comparisons: 64961
# Current Threshold Value: 25
# Time Elapsed: 0.0262 seconds
# Number of Key Comparisons: 64961
# Current Threshold Value: 30
# Time Elapsed: 0.0262 seconds
# Number of Key Comparisons: 64961
# Current Threshold Value: 35
# Time Elapsed: 0.0261 seconds
# Number of Key Comparisons: 64961
# Current Threshold Value: 40
# Time Elapsed: 0.0309 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 45
# Time Elapsed: 0.0311 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 50
# Time Elapsed: 0.0310 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 55
# Time Elapsed: 0.0308 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 60
# Time Elapsed: 0.0307 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 65
# Time Elapsed: 0.0309 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 70
# Time Elapsed: 0.0308 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 75
# Time Elapsed: 0.0310 seconds
# Number of Key Comparisons: 84939
# Current Threshold Value: 80
# Time Elapsed: 0.0430 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 85
# Time Elapsed: 0.0432 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 90
# Time Elapsed: 0.0431 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 95
# Time Elapsed: 0.0430 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 100
# Time Elapsed: 0.0428 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 105
# Time Elapsed: 0.0427 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 110
# Time Elapsed: 0.0428 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 115
# Time Elapsed: 0.0429 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 120
# Time Elapsed: 0.0429 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 125
# Time Elapsed: 0.0428 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 130
# Time Elapsed: 0.0427 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 135
# Time Elapsed: 0.0427 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 140
# Time Elapsed: 0.0427 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 145
# Time Elapsed: 0.0433 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 150
# Time Elapsed: 0.0432 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 155
# Time Elapsed: 0.0431 seconds
# Number of Key Comparisons: 130237
# Current Threshold Value: 160
# Time Elapsed: 0.0685 seconds
# Number of Key Comparisons: 220171
# Current Threshold Value: 165
# Time Elapsed: 0.0691 seconds
# Number of Key Comparisons: 220171
# Current Threshold Value: 170
# Time Elapsed: 0.0688 seconds
# Number of Key Comparisons: 220171
# Current Threshold Value: 175
# Time Elapsed: 0.0681 seconds
# Number of Key Comparisons: 220171
# Current Threshold Value: 180
# Time Elapsed: 0.0683 seconds
# Number of Key Comparisons: 220171
# Current Threshold Value: 185
# Time Elapsed: 0.0704 seconds
# Number of Key Comparisons: 220171
# Optimal Threshold: 20
# Time Taken for Optimal Threshold: 0.0250

# %%
## Plot the Graph
# Plot the Points
plt.plot(fixedArraySizeXCoordinates, fixedArraySizeYCoordinates)

# Naming the Axes
plt.xlabel("Threshold Values S")
plt.ylabel("Number of Key Comparisons")
plt.title("Graph of number of Key Comparisons over different Threshold Values S")
plt.show()

# %% [markdown]
# #### Compare Empirical Results with Theoretical Analysis for Time Complexity

# %% [markdown]
# - According to our Hybrid Sort Implementation, as the threshold value S increases, the probability of likelihood of using insertion sort to sort the entire array increases. This means that even if I use a fixed extremely large array size, the number of splits using merge sort would decreases as S increases. Eventually, only Insertion Sort will be used.
# - Hence, it makes sense for the number of key comparisons to increases as S increases.
# - The reason for the sudden spikes in key comparisons can be explained by Merge Sort. For some threshold value S, there will be some k splits due to Merge Sort at a certain array size, causing the number of key comparisons to increases as S increases since k splits becomes smaller and smaller.

# %% [markdown]
# c) iii) Using different sizes of input datasets, study how to determine an optimal value of S for the best performance of this hybrid algorithm.

# %%
# Array to store the list of potential optimal threshold values and their minimum times
potentialThresholdValueArray = []
potentialThresholdTimesArray = []

# Create Arrays to store X and Y Coordinates
fixedArraySizeXCoordinates2 = []
fixedArraySizeYCoordinates2 = []

# For a given input data size, vary the threshold value S to determine the optimal threshold value for this Dataset
for i in range(20):
    array1 = []
    array2 = []
    determineOptimalThreshold(0, inputData[i], potentialThresholdValueArray, potentialThresholdTimesArray, array1, array2, inputData)
    fixedArraySizeXCoordinates2.append(array1)
    fixedArraySizeYCoordinates2.append(array2)

# The most frequent (mode) threshold value is the optimum threshold value
modeThreshold = max(set(potentialThresholdValueArray), key=potentialThresholdValueArray.count)
print(modeThreshold)
# Out:
# Current Threshold Value: 5
# Time Elapsed: 0.0042 seconds
# Number of Key Comparisons: 8429
# Current Threshold Value: 10
# Time Elapsed: 0.0041 seconds
# Number of Key Comparisons: 8729
# Current Threshold Value: 15
# Time Elapsed: 0.0039 seconds
# Number of Key Comparisons: 9099
# Current Threshold Value: 20
# Time Elapsed: 0.0042 seconds
# Number of Key Comparisons: 9879
# Current Threshold Value: 25
# Time Elapsed: 0.0040 seconds
# Number of Key Comparisons: 9879
# Current Threshold Value: 30
# Time Elapsed: 0.0041 seconds
# Number of Key Comparisons: 9879
# Current Threshold Value: 35
# Time Elapsed: 0.0047 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 40
# Time Elapsed: 0.0047 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 45
# Time Elapsed: 0.0047 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 50
# Time Elapsed: 0.0048 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 55
# Time Elapsed: 0.0048 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 60
# Time Elapsed: 0.0047 seconds
# Number of Key Comparisons: 12946
# Current Threshold Value: 65
# Time Elapsed: 0.0066 seconds
# Number of Key Comparisons: 19534
# Current Threshold Value: 70
# Time Elapsed: 0.0066 seconds
# Number of Key Comparisons: 19534
# Current Threshold Value: 75
# Time Elapsed: 0.0065 seconds
# Number of Key Comparisons: 19534
# Time Elapsed: 0.3333 seconds
# Number of Key Comparisons: 751075
# Current Threshold Value: 20
# Time Elapsed: 0.3371 seconds
# Number of Key Comparisons: 751075
# Current Threshold Value: 25
# Time Elapsed: 0.3587 seconds
# Number of Key Comparisons: 863529
# Current Threshold Value: 30
# Time Elapsed: 0.3564 seconds
# Number of Key Comparisons: 863529
# Current Threshold Value: 35
# Time Elapsed: 0.3567 seconds
# Number of Key Comparisons: 863529
# Current Threshold Value: 40
# Time Elapsed: 0.3582 seconds
# Number of Key Comparisons: 863529
# Current Threshold Value: 45
# Time Elapsed: 0.3562 seconds
# Number of Key Comparisons: 863529
# Current Threshold Value: 50
# Time Elapsed: 0.4216 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 55
# Time Elapsed: 0.4221 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 60
# Time Elapsed: 0.4221 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 65
# Time Elapsed: 0.4217 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 70
# Time Elapsed: 0.4217 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 75
# Time Elapsed: 0.4214 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 80
# Time Elapsed: 0.4228 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 85
# Time Elapsed: 0.4221 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 90
# Time Elapsed: 0.4222 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 95
# Time Elapsed: 0.4220 seconds
# Number of Key Comparisons: 1125392
# Current Threshold Value: 100
# Time Elapsed: 0.5770 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 105
# Time Elapsed: 0.5770 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 110
# Time Elapsed: 0.5759 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 115
# Time Elapsed: 0.5763 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 120
# Time Elapsed: 0.5773 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 125
# Time Elapsed: 0.5768 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 130
# Time Elapsed: 0.5773 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 135
# Time Elapsed: 0.5769 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 140
# Time Elapsed: 0.5761 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 145
# Time Elapsed: 0.5763 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 150
# Time Elapsed: 0.5777 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 155
# Time Elapsed: 0.5754 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 160
# Time Elapsed: 0.5763 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 165
# Time Elapsed: 0.5761 seconds
# Number of Key Comparisons: 1689660
# Current Threshold Value: 170
# Time Elapsed: 0.5780 seconds
# Time Elapsed: 0.7463 seconds
# Number of Key Comparisons: 1827364
# Current Threshold Value: 30
# Time Elapsed: 0.7463 seconds
# Number of Key Comparisons: 1827364
# Current Threshold Value: 35
# Time Elapsed: 0.7476 seconds
# Number of Key Comparisons: 1827364
# Current Threshold Value: 40
# Time Elapsed: 0.7455 seconds
# Number of Key Comparisons: 1827364
# Current Threshold Value: 45
# Time Elapsed: 0.7462 seconds
# Number of Key Comparisons: 1827364
# Current Threshold Value: 50
# Time Elapsed: 0.8738 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 55
# Time Elapsed: 0.8761 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 60
# Time Elapsed: 0.8748 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 65
# Time Elapsed: 0.8731 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 70
# Time Elapsed: 0.8732 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 75
# Time Elapsed: 0.8731 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 80
# Time Elapsed: 0.8733 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 85
# Time Elapsed: 0.8753 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 90
# Time Elapsed: 0.8757 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 95
# Time Elapsed: 0.8733 seconds
# Number of Key Comparisons: 2349816
# Current Threshold Value: 100
# Time Elapsed: 1.1744 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 105
# Time Elapsed: 1.1774 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 110
# Time Elapsed: 1.1738 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 115
# Time Elapsed: 1.1762 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 120
# Time Elapsed: 1.1827 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 125
# Time Elapsed: 1.1890 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 130
# Time Elapsed: 1.1851 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 135
# Time Elapsed: 1.1814 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 140
# Time Elapsed: 1.1874 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 145
# Time Elapsed: 1.1845 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 150
# Time Elapsed: 1.1784 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 155
# Time Elapsed: 1.1794 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 160
# Time Elapsed: 1.1829 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 165
# Time Elapsed: 1.1810 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 170
# Time Elapsed: 1.1765 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 175
# Time Elapsed: 1.1810 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 180
# Time Elapsed: 1.1773 seconds
# Number of Key Comparisons: 3477415
# Current Threshold Value: 185
# Time Elapsed: 1.1774 seconds
# Number of Key Comparisons: 3477415
# Optimal Threshold: 30
# Time Taken for Optimal Threshold: 0.7049
# Current Threshold Value: 5
# Time Elapsed: 1.5809 seconds
# Number of Key Comparisons: 3198442
# Current Threshold Value: 10
# Time Elapsed: 1.5193 seconds
# Number of Key Comparisons: 3240403
# Current Threshold Value: 15
# Time Elapsed: 1.5053 seconds
# Number of Key Comparisons: 3403186
# Current Threshold Value: 20
# Time Elapsed: 1.5050 seconds
# Number of Key Comparisons: 3403186
# Current Threshold Value: 25
# Time Elapsed: 1.5816 seconds
# Number of Key Comparisons: 3846205
# Current Threshold Value: 30
# Time Elapsed: 1.5814 seconds
# Number of Key Comparisons: 3846205
# Current Threshold Value: 35
# Time Elapsed: 1.5794 seconds
# Number of Key Comparisons: 3846205
# Current Threshold Value: 40
# Time Elapsed: 1.5827 seconds
# Number of Key Comparisons: 3846205
# Current Threshold Value: 45
# Time Elapsed: 1.5838 seconds
# Number of Key Comparisons: 3846205
# Current Threshold Value: 50
# Time Elapsed: 1.8918 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 55
# Time Elapsed: 1.8501 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 60
# Time Elapsed: 1.8386 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 65
# Time Elapsed: 1.8394 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 70
# Time Elapsed: 1.8368 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 75
# Time Elapsed: 1.8355 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 80
# Time Elapsed: 1.8346 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 85
# Time Elapsed: 1.8372 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 90
# Time Elapsed: 1.8362 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 95
# Time Elapsed: 1.8387 seconds
# Number of Key Comparisons: 4887504
# Current Threshold Value: 100
# Time Elapsed: 2.4469 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 105
# Time Elapsed: 2.4617 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 110
# Time Elapsed: 2.4449 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 115
# Time Elapsed: 2.4484 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 120
# Time Elapsed: 2.4514 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 125
# Time Elapsed: 2.4538 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 130
# Time Elapsed: 2.4470 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 135
# Time Elapsed: 2.4482 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 140
# Time Elapsed: 2.4457 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 145
# Time Elapsed: 2.4425 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 150
# Time Elapsed: 2.4376 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 155
# Time Elapsed: 2.4431 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 160
# Time Elapsed: 2.4385 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 165
# Time Elapsed: 2.4455 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 170
# Time Elapsed: 2.4441 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 175
# Time Elapsed: 2.4458 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 180
# Time Elapsed: 2.4422 seconds
# Number of Key Comparisons: 7140922
# Current Threshold Value: 185
# Time Elapsed: 2.4420 seconds
# Number of Key Comparisons: 7140922
# Optimal Threshold: 40
# Time Taken for Optimal Threshold: 1.5050
# 30

# %%
# Determine the Index of the Optimal Value
optimalThresholdIndex = potentialThresholdValueArray.index(modeThreshold)

# Plot the Graph
for graph in range(len(fixedArraySizeXCoordinates2)):
    plt.plot(fixedArraySizeXCoordinates2[graph], fixedArraySizeYCoordinates2[graph], label = "Array of Size {}".format(len(inputData[graph])))

plt.xlabel("Threshold Values S")
plt.ylabel("Number of Key Comparisons")
plt.title("Graph of number of Key Comparisons over different Threshold Values S at different Array Sizes")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.4))
plt.show()

# Print the Optimum Threshold Value
print("The Optimum Threshold is", modeThreshold)
# Out:
# The Optimum Threshold is 30

# %% [markdown]
# - Using arrays of various sizes, each array X has their threshold values S varied, so as to determine the number of key comparisons required and the time taken at each S and array size.
# - Using a min() function, the threshold value S with the smallest CPU times is added into an array Y which stores the candidates for potential optimal threshold values S at each array size.
# - Finally, a mode function is implemented and the S value that appeared the most frequently is selected as the optimum threshold the works for multiple array sizes, which is 110 in this case.

# %%
np.random.seed(22)

optimalS = 0
arraySize = range(0,20)
mergeComparisons = []
insertionComparisons = []
mergeComparison = 0
mergeObject = KeyComparisons()
insertObject = KeyComparisons()

for s in arraySize:
    arr = np.random.randint(10000,size = s)
    arr2 = arr.copy()
    arr = mergeSort(arr, mergeObject, 2)
    mergeComparison = mergeObject.returnKeyComparisons()
    mergeObject.resetKeyComparisons()
    
    arr2 = insertionSort(arr2, insertObject)
    insertionComparison = insertObject.returnKeyComparisons()
    insertObject.resetKeyComparisons()
    
    if insertionComparison < mergeComparison:
        optimalS = s
    mergeComparisons.append(mergeComparison)
    insertionComparisons.append(insertionComparison)
    

f = plt.figure(figsize=(20,20))
ax = f.add_subplot(211)
ax.plot(arraySize,mergeComparisons, label="MergeSort") 
ax.plot(arraySize, insertionComparisons, label = "InsertionSort")
ax.set_xlabel("Array Size")
ax.set_ylabel("Key Comparisons")
ax.set_title("Key Comparisons against Array Size for Merge/Insertion Sort")
ax.legend()

print('Optimal S is:', optimalS)
# Out:
# Optimal S is: 9

# %% [markdown]
# ### d) Compare with Original Mergesort: Implement the original mergesort. Compare its performance against the above hybrid algorithm in terms of the number of key comparisons and CPU times on the dataset with 10 million integers. Use the optimal value of S obtained in (c) for this task

# %%
def mergeSort(arr, comparisonsObject, criterion):
    # Use the middle element to divide the array into two halves
    m = len(arr)//2

    # Base case. Array has 1 element.
    if len(arr) <= 1:
        return arr
    
    # Recursive step
    if len(arr) > criterion:
        # Sort first half recursively
        arr[:m] = mergeSort(arr[:m], comparisonsObject, criterion)
        # Sort second half recursively
        arr[m:] = mergeSort(arr[m:], comparisonsObject, criterion)
    arr = merge(arr[:m], arr[m:], comparisonsObject)
    
    return arr

# Initial Initialisation
targetArray = copy.deepcopy(inputData[36])
compareMergeAndHybrid = KeyComparisons()

# Determine Merge Sort CPU Times & Key Comparisons
mergeSortStartTime = time.time()
mergeSort(targetArray, compareMergeAndHybrid, 2)    # Don't think Optimal Threshold applies to MergeSort as well
mergeSortEndTime = time.time()

mergeSortTimeTaken = mergeSortEndTime - mergeSortStartTime
print("Merge Sort CPU Times: {0:.2f} seconds".format(mergeSortTimeTaken))
print("Number of Key Comparisons for Merge Sort: {}".format(compareMergeAndHybrid.returnKeyComparisons()))

# Reinitialise Arrays and Objects
targetArray = copy.deepcopy(inputData[36])
compareMergeAndHybrid.resetKeyComparisons()

# Determine the Same for Hybrid Sort
hybridSortStartTime = time.time()
hybridSort(targetArray, 9, compareMergeAndHybrid)
hybridSortEndTime = time.time()

hybridSortTimeTaken = hybridSortEndTime - hybridSortStartTime
print("Hybrid Sort CPU Times: {0:.2f} seconds".format(hybridSortTimeTaken))
print("Number of Key Comparisons for Hybrid Sort: {}".format(compareMergeAndHybrid.returnKeyComparisons()))
# Out:
# Merge Sort CPU Times: 113.28 seconds
# Number of Key Comparisons for Merge Sort: 216319717
# Hybrid Sort CPU Times: 103.15 seconds
# Number of Key Comparisons for Hybrid Sort: 219366902

# %% [markdown]
# #### Hence, Hybrid Sort is more efficient as it has a shorter running time, despite having more key comparisons.

# %% [markdown]
# - S based on times. Maybe need seed values or just pick one
# - Cannot +1 for Threshold as I will get 130 which is not optimal.
