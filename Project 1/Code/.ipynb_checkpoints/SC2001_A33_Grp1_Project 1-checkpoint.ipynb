# %% [markdown]
# # SC2001 Project 1 (Lab Group A33, Group 1)
# ## Integration of Mergesort & Insertion Sort

# %% [markdown]
# > In Mergesort, when the sizes of subarrays are small, the overhead of many recursive calls makes the algorithm inefficient. Therefore, in real use, we often combine Mergesort with Insertion Sort to come up with a hybrid sorting algorithm for better efficiency. The idea is to set a small integer S as a threshold for the size of subarrays. <br><br>
# > Once the size of a subarray in a recursive call of Mergesort is less than or equal to S, the algorithm will switch to Insertion Sort, which is efficient for small-sized input.

# %%
# Imports
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Setting seed to ensure that our data does not change in the future.
np.random.seed(10)

# %% [markdown]
# ### a) Algorithm Implementation

# %% [markdown]
# > Implement the above hybrid algorithm.

# %%
# Create an Object to store the Number of Key Comparisons in our Sorting Methods
class KeyComparisons:
    def __init__(self):
        self.numKeyComparisons = 0

    def isALargerThanB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a > b

    def isALessThanB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a < b

    def isAEqualB(self, a, b) -> bool:
        self.numKeyComparisons += 1
        return a == b

    def incrementKeyComparisons(self, incrementValue):
        self.numKeyComparisons += incrementValue

    def resetKeyComparisons(self):
        self.numKeyComparisons = 0
        
    def returnKeyComparisons(self):
        return self.numKeyComparisons
        

# Declaring a Constant for Fixed Threshold Value
def FIXED_THRESHOLD_VALUE():
    return 10

# %% [markdown]
# ### Insertion Sort

# %%
def insertionSort(arr, comparisonsObject):
    
    # Traverse for each element from index 1 to end of list. First element can be ignored.
    for i in range(1, len(arr)):
        key = arr[i] # Pick out the element at the i-th position
        j = i-1 # j will be the running index for all the elements before elem
        
        while j >= 0 and comparisonsObject.isALessThanB(key, arr[j]): # While it hasn't reached the first element and the key is smaller than the previous elements, we will shift the j-th element to the j+1-th position
            arr[j+1] = arr[j]
            j -= 1
           
        arr[j+1] = key # If we reach an element that is smaller than the key or the start of the list (j=-1), we will insert the key to the right of that element or at index 0 if it reached start of list.
    return arr

# %% [markdown]
# ### Merge Sort

# %%
def mergeSort(arr, comparisonsObject):
    # Base case. Array has 1 element.
    if len(arr) <= 1:
        return arr
    
    # Recursive step
    
    # Use the middle element to divide the array into two halves
    m = len(arr)//2

    # Sort first half recursively
    arr[:m] = hybridSort(arr[:m],S, comparisonsObject)
    # Sort second half recursively
    arr[m:] = hybridSort(arr[m:], S, comparisonsObject)
    arr = merge(arr[:m], arr[m:], comparisonsObject)
    return arr

# %% [markdown]
# ### Hybrid Sort

# %%
# Merge function which will be used in the hybrid sort when merge sort is chosen over insertion sort.

def merge(arr1, arr2, comparisonsObject):
    # initialise indices for each array
    i = 0
    j = 0
    
    # initialise final sorted array
    sorted_arr = []
    
    # While both halves are not empty, we compare the 1st elements of the 2 lists
    while i != len(arr1) and j != len(arr2):
        # Keeping track of the Number of Comparisons
        
        # if first element of 1st list is smaller, 1st element of first half joins the end of the merged list
        if comparisonsObject.isALessThanB(arr1[i], arr2[j]):
            sorted_arr.append(arr1[i])
            i += 1
        # else if 1st element of 2nd list is smaller, move the 1st element of 2nd half to the end of the merged list
        elif arr2[j] < arr1[i]:
            sorted_arr.append(arr2[j])
            j += 1
        # else if they are equal, move both the 1st element of the first list and the second list to the merged list
        else:
            sorted_arr.append(arr1[i])
            sorted_arr.append(arr2[j])
            i += 1
            j += 1
    # if first list still has elements, copy all the elements in the first list to the merged list
    while i != len(arr1):
        sorted_arr.append(arr1[i])
        i += 1
    # if second list still has elements, copy all the elements in the second list to the merged list
    while j != len(arr2):
        sorted_arr.append(arr2[j])
        j += 1
    return sorted_arr

# %%
# Hybrid Sort takes in parameters of an array and array size limit S.
# If array size is <= S, insertion sort will be used 
# If array size is > S , merge sort will be used instead

def hybridSort(arr,S, comparisonsObject):
    # Base case. Array has 1 element.
    if len(arr) <= 1:
        return arr
    
    # Recursive step
    
    # Merge Sort 
    if len(arr) > S:
        # Use the middle element to divide the array into two halves
        m = len(arr)//2
        
        # Sort first half recursively
        arr[:m] = hybridSort(arr[:m],S, comparisonsObject)
        # Sort second half recursively
        arr[m:] = hybridSort(arr[m:], S, comparisonsObject)
        arr = merge(arr[:m], arr[m:], comparisonsObject)
        return arr
    
    # Insertion Sort
    else:
        arr = insertionSort(arr, comparisonsObject)
        return arr

# %% [markdown]
# ### Testing the sorting algorithms

# %%
arr = [4,2,10,100,3,59,43,-1,-8,0,7,12,11,3,3,3]
comparisonsObject = KeyComparisons(0)   

print(hybridSort(arr,3, comparisonsObject))
# Out:
# [-8, -1, 0, 2, 3, 3, 3, 3, 4, 7, 10, 11, 12, 43, 59, 100]

# %% [markdown]
# ## b) Generate input data

# %% [markdown]
# > Generate arrays of increasing sizes, in a range from
# 1,000 to 10 million. For each of the sizes, generate a random dataset of integers in the range of [1, …, x], where x is the largest number you allow for your datasets.

# %%
# Generate the required sizes of the arrays programatically from the range of 1,000 to 10 million.

inputDataSizes = []

for i in range(10):
    inputDataSizes.append((i+1) * 1000)
    inputDataSizes.append((i+1) * 10000)
    inputDataSizes.append((i+1) * 100000)
    inputDataSizes.append((i+1) * 1000000)

# Remove duplicates and sort the input data sizes
inputDataSizes = sorted(set(inputDataSizes))
print(inputDataSizes)
# Out:
# [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000, 200000, 300000, 400000, 500000, 600000, 700000, 800000, 900000, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000, 10000000]

# %%
# List of List of data
inputData = []

# Iterate through the data sizes array
for s in inputDataSizes:
    # For each datasize, we generate a random data array of size (s), each array will contain random integers from 1 to s.
    data = np.random.randint(1,s+1,size = s)
    inputData.append(data)
    
# Checking for the array of size 1000 that the generation was done correctly.    
for i in range(len(inputData)):
    print("Array Size: ", len(inputData[i]))
    print("Min of this array:" , min(inputData[i]))
    print("Max of this array:" , max(inputData[i]))
    print()
# Out:
# Array Size:  1000
# Min of this array: 1
# Max of this array: 999
#
# Array Size:  2000
# Min of this array: 3
# Max of this array: 1998
#
# Array Size:  3000
# Min of this array: 2
# Max of this array: 2998
#
# Array Size:  4000
# Min of this array: 1
# Max of this array: 4000
#
# Array Size:  5000
# Min of this array: 3
# Max of this array: 4999
#
# Array Size:  6000
# Min of this array: 1
# Max of this array: 5999
#
# Array Size:  7000
# Min of this array: 1
# Max of this array: 6999
#
# Array Size:  8000
# Min of this array: 2
# Max of this array: 7999
#
# Array Size:  9000
# Min of this array: 4
# Max of this array: 9000
#
# Array Size:  10000
# Min of this array: 2
# Max of this array: 10000
#
# Array Size:  20000
# Min of this array: 1
# Max of this array: 19999
#
# Array Size:  30000
# Min of this array: 1
# Max of this array: 30000
#
# Array Size:  40000
# Min of this array: 1
# Max of this array: 39998
#
# Array Size:  50000
# Min of this array: 3
# Max of this array: 50000
#
# Array Size:  60000
# Min of this array: 1
# Max of this array: 59999
#
# Array Size:  70000
# Min of this array: 1
# Max of this array: 70000
#
# Array Size:  80000
# Min of this array: 2
# Max of this array: 80000
#
# Array Size:  90000
# Min of this array: 1
# Max of this array: 90000
#
# Array Size:  100000
# Min of this array: 1
# Max of this array: 100000
#
# Array Size:  200000
# Min of this array: 3
# Max of this array: 199997
#
# Array Size:  300000
# Min of this array: 2
# Max of this array: 299999
#
# Array Size:  400000
# Min of this array: 2
# Max of this array: 400000
#
# Array Size:  500000
# Min of this array: 2
# Max of this array: 499997
#
# Array Size:  600000
# Min of this array: 1
# Max of this array: 600000
#
# Array Size:  700000
# Min of this array: 5
# Max of this array: 700000
#
# Array Size:  800000
# Min of this array: 2
# Max of this array: 799999
#
# Array Size:  900000
# Min of this array: 2
# Max of this array: 900000
#
# Array Size:  1000000
# Min of this array: 2
# Max of this array: 1000000
#
# Array Size:  2000000
# Min of this array: 1
# Max of this array: 2000000
#
# Array Size:  3000000
# Min of this array: 1
# Max of this array: 3000000
#
# Array Size:  4000000
# Min of this array: 1
# Max of this array: 3999999
#
# Array Size:  5000000
# Min of this array: 1
# Max of this array: 5000000
#
# Array Size:  6000000
# Min of this array: 1
# Max of this array: 5999998
#
# Array Size:  7000000
# Min of this array: 3
# Max of this array: 7000000
#
# Array Size:  8000000
# Min of this array: 1
# Max of this array: 8000000
#
# Array Size:  9000000
# Min of this array: 2
# Max of this array: 8999997
#
# Array Size:  10000000
# Min of this array: 1
# Max of this array: 9999998

# %%
print(inputData[0])
# Out:
# [266 126 997 528 321 370 124 157 986 734 497 926 882   9  74 257 491  41
#  503 421 372 529 357 240 396  55 345 364 123 575 546 201 869 975 690 692
#   55  78 454  14 756 410 383 654 861 343 799 671  90 653 322 544 826 805
#  284 531  94  78 407 920 607 761 396 669  75 217 394  16 531 465 631  72
#  345 396 658 431 136 716 797 802 469 763 865 473  45 646   5  72 345 857
#  819 365 183 291 361 784 462 857 656 135 247 598 747 663 524 625 781 733
#  481  63 503 186 592 365 233 555 750 314 748 866 819 558 937 986 714 678
#  641 915 536 516 798 785 341 339 625 527  52  80 244 786 691  54 922 367
#  945 235 786 417 338 746 465  42  91 269 499 287 210 402 145 129 672 358
#  202 961 757 381 423 767 535 609 835  68 447  96 356 924  83  63 759 590
#  507 364  49 374 990 750 460 628 471 422 780 918 930 608 684 985 737 742
#   74 681 358 428 748 347 584 649 726 329 413 256 878 543 124 986 666 207
#  466 214 959  14 682 930 517 728 351 541 552 348 104 778 264 151  33 772
#  522 181 973 709 159 455 377 885 331 799 138 259 962 507 999 628 491 654
#  460 437 646 222 341 945 959 811 675 169  47 929 504 351  87 187 454 377
#  814  19 435 497 557 386 320 876 718 531 924 596 678 456 473 104 656  56
#  903 813  10 819   1 557 325 271 494 118 389 903  43 202 557 369 764 997
#  475 807 405 906 553 657 332 424 315 210 552 562 128 994 396 207 363 848
#  534 454 433 317 827 398 361 516 928 205 472 146 926 454 691 564 661   6
#  248 877 711 190 233 913 715 645 919 788 598 714 292 633 292 113 268 554
#  311 979  20 298 978 702 395  37 513 252 159 831 598 289 491 617 978 270
#  964 247 893 928 289 737 935 166 208 188 360 533 928  90 637 257 353 282
#  576 828 259 543  18 828 199 960  87 542 107 712 349 276 506 641 392 252
#  478 939 600 826 763 209   3 675  59 461 651  80 929 838 761 220 145 518
#  890  64 852 844 683 890 423 186 136 985 737 874 551 879 561 668 366 321
#  690 475 266 284 309 347 826 945 114 363  24 410 660 561 489 738 333 588
#  606 287 800 157 102 976 213 150 725 228 687 943 302 479 853 149 434 290
#  643 482 866 227 781 339 495 206  67 550 672 313 210 344 466 383  56 866
#  587 761  16 976 849  39 440 886  50 987 643 839 738 902 969 542 497 276
#   26  16 183 612 481 851 697 554 347  27 459   9 477 161 328 344 965 215
#   15 292 469 112 678 112 575 580 527 678 826 975 621 291 948 819 179 470
#   15 889 437 927  82 999 523 830 280 130 541 571 267 248 524 898 510 211
#  675 120 652  47 331 677 903 576 760 317   4 307  60 762 163 662 401 872
#  147  62 695 635 957 406 383 984  84 584 145 452 679 668 481 728  99  90
#  758 242 657 595 660 754 627 865  51 985 489 137 983 118 460 201 601 233
#  155 337 119 413 155 863 642 348 899 729 317 436 654 334 794 190 425 391
#  872 112 934  82  71 378 935 766 108 504 742 479 259 933 331 313 922 467
#  481 827 401 471 383 297 608 239 423   5 408  59 936 129 423 885 463 622
#  458 237 232 283 850 646 258 397 228  87 372 498   1 200   1 827 539 788
#  467 968 902 542 258 318 157 903 854 244 344 348 627 772 869 391 741 611
#   92 567 649 841 523 106 698 341 389 216 450 392  73 940 561 345 890 171
#   22 728 111 915 276 463 742 228 161 664 728 944 825 304 803 225 356 786
#  490 353  97 368 510 403 638 837 131 528 938 456  98 875 564 582 165 715
#   29 850 312 201 391 273 896 789 516 433 461 589 187  66 595 792 537 457
#  311 977 628  22 695 660 352 311   4 624 611 410 682  15 714 584 167 434
#  791 625 610  48 160 815  99 390 399 845 273 221 533 467 266 825 678 611
#  263 671 580 968 199 310 185 270 380 779 573 640 639 546 939 129 473 951
#  569 677 984 879 835 503 615 518 184 914 770 714 436 974 142 994 520 510
#  795 523 501 751 255 167 889 266 867 935 951 699 674 791 859 329 439 580
#  297 767 989 944 688 744 771 109 536 238 894 416 834 569 805 600 645 591
#  100 316 727 287 941 616 773 728 294 879 768 835 572 548 579 698 187 769
#  693 136 123 670  43 755 457 721 755 520 161  85 972 269 593 758 615 101
#  993 970 322 550 585 238 424 543 296 582 168 609 186 995 793 264 852 486
#  298  20 998 632 921 929  16 215 117 162 255 358  67 458 399 294 665 506
#   84  20  64 848 932 710 352 630 474 636 826 548  95 868 759 323 915 252
#  261 640 972 481 832 653 603  59 459 912]

# %% [markdown]
# ## c) Analyse Time Complexity

# %% [markdown]
# > ### Run your program of the hybrid algorithm on the datasets generated in Step (b). Record the number of key comparisons performed in each case.
#
# > c)i) With the value of S fixed, plot the number of key comparisons over different sizes of the input list n. Compare your empirical results with your theoretical analysis of the time complexity.

# %% [markdown]
# ### Theoretical Analysis of the time complexity

# %% [markdown]
# Using the hybrid algorithm, we perform Insertion Sort when the size of the n/s (n elements / s threshold size) array is below a threshold s. Then, we are performing Insertion Sort on arrays, where each array is size s.
#
# We know the average and worst-case time complexity of Insertion Sort is *O(s^2)*. Thus, the total time complexity of the Insertion Sort component of our hybrid algorithm is:
#
#     n/s x *O(s^2)*
#     = O(ns)*
#
# If we consider the best-case, then the total time complexity will be:
#
#     n/s x *O(s)*
#     = *O(n)*
#
# Next, performing the Merge operation on the sorted arrays. In traditional Merge Sort, this Merge operation is done on log n levels. However, since we switched to Insertion Sort wherein the array size is fixed at s, the Merge operation is only called on log (n/s) levels.
#
# Each level compares n elements. Therefore, the total time complexity of the Merge Sort component of our hybrid algorithm is:
#
#     n x log (n/s) = *O(n log (n/s))*
#
# Hence, the total time complexity of the hybrid algorithm is:
#
#     At worst and average-case: *O(ns + n log (n/s))*
#
#     At best-case: *O(n + n log (n/s))*
#
# Compare with Empirical Data
#     When s is fixed, the time complexity of the hybrid algorithm can be simplified to *O(n + n log n)* = *O(n log n) , so long as s* does not approach n.
#
# Since we set our s to be very small (10), we expect our time complexity to be:
#
#      *O(n log n)*.
#
# We note that the hybrid algorithm does more key comparisons than the merge sort algorithm. This is to be expected since the hybrid algorithm incorporated the Insertion Sort algorithm, whose runtime is *O(n2)* => more key comparisons than *O(n log n)*.
#
# We note that the hybrid algorithm has a lower elapsed time than the merge sort algorithm. This is also to be expected since the small sub-arrays are sorted more quickly using Insertion Sort, resulting in lesser elapsed time.

# %% [markdown]
# # Can show the comparison of the number of comparisons and elapsed time

# %%
# Fix the Threshold Value S
thresholdValueS = FIXED_THRESHOLD_VALUE()

# Create Arrays to store X and Y Coordinates
fixedThresholdXCoordinates = []
fixedThresholdYCoordinates = []

# Run Hybrid Sort over each Individual Array
for array in inputData:
    arrayLength = len(array)
    print("Current Array Size: {}".format(arrayLength))
    
    # Create Timestamps to track the time taken for the Hybrid Sort to sort this Array
    startTimestamp = time.time()
    hybridSort(array, thresholdValueS, comparisonsObject)
    endingTimestamp = time.time()

    # Record the KeyComparisons (Y) and Different Threshold Values S(X)
    numKeyComparisons1 = comparisonsObject.returnKeyComparisons()
    fixedThresholdXCoordinates.append(arrayLength)
    fixedThresholdYCoordinates.append(numKeyComparisons1)

    # Print Time Taken & Num Key Comparisons
    print("Time Elapsed for Hybrid Sort: {0:.2f} seconds".format(endingTimestamp - startTimestamp))
    print("Number of Key Comparisons: {}".format(numKeyComparisons1))
    
    # Reset the Number of Key Comparisons for Next Array
    comparisonsObject.resetKeyComparisons()
# Out:
# Current Array Size: 1000
# Time Elapsed for Hybrid Sort: 0.00 seconds
# Number of Key Comparisons: 5257
# Current Array Size: 2000
# Time Elapsed for Hybrid Sort: 0.01 seconds
# Number of Key Comparisons: 11497
# Current Array Size: 3000
# Time Elapsed for Hybrid Sort: 0.01 seconds
# Number of Key Comparisons: 18697
# Current Array Size: 4000
# Time Elapsed for Hybrid Sort: 0.01 seconds
# Number of Key Comparisons: 25078
# Current Array Size: 5000
# Time Elapsed for Hybrid Sort: 0.01 seconds
# Number of Key Comparisons: 31384
# Current Array Size: 6000
# Time Elapsed for Hybrid Sort: 0.02 seconds
# Number of Key Comparisons: 40335
# Current Array Size: 7000
# Time Elapsed for Hybrid Sort: 0.02 seconds
# Number of Key Comparisons: 47184
# Current Array Size: 8000
# Time Elapsed for Hybrid Sort: 0.03 seconds
# Number of Key Comparisons: 54014
# Current Array Size: 9000
# Time Elapsed for Hybrid Sort: 0.03 seconds
# Number of Key Comparisons: 60838
# Current Array Size: 10000
# Time Elapsed for Hybrid Sort: 0.03 seconds
# Number of Key Comparisons: 67744
# Current Array Size: 20000
# Time Elapsed for Hybrid Sort: 0.07 seconds
# Number of Key Comparisons: 145315
# Current Array Size: 30000
# Time Elapsed for Hybrid Sort: 0.11 seconds
# Number of Key Comparisons: 232002
# Current Array Size: 40000
# Time Elapsed for Hybrid Sort: 0.15 seconds
# Number of Key Comparisons: 310409
# Current Array Size: 50000
# Time Elapsed for Hybrid Sort: 0.20 seconds
# Number of Key Comparisons: 412090
# Current Array Size: 60000
# Time Elapsed for Hybrid Sort: 0.24 seconds
# Number of Key Comparisons: 494062
# Current Array Size: 70000
# Time Elapsed for Hybrid Sort: 0.28 seconds
# Number of Key Comparisons: 577680
# Current Array Size: 80000
# Time Elapsed for Hybrid Sort: 0.32 seconds
# Number of Key Comparisons: 660934
# Current Array Size: 90000
# Time Elapsed for Hybrid Sort: 0.39 seconds
# Number of Key Comparisons: 783718
# Current Array Size: 100000
# Time Elapsed for Hybrid Sort: 0.43 seconds
# Number of Key Comparisons: 873981
# Current Array Size: 200000
# Time Elapsed for Hybrid Sort: 0.92 seconds
# Number of Key Comparisons: 1847834
# Current Array Size: 300000
# Time Elapsed for Hybrid Sort: 1.35 seconds
# Number of Key Comparisons: 2778656
# Current Array Size: 400000
# Time Elapsed for Hybrid Sort: 1.93 seconds
# Number of Key Comparisons: 3896102
# Current Array Size: 500000
# Time Elapsed for Hybrid Sort: 2.39 seconds
# Number of Key Comparisons: 4869340
# Current Array Size: 600000
# Time Elapsed for Hybrid Sort: 2.86 seconds
# Number of Key Comparisons: 5857408
# Current Array Size: 700000
# Time Elapsed for Hybrid Sort: 3.50 seconds
# Number of Key Comparisons: 7041603
# Current Array Size: 800000
# Time Elapsed for Hybrid Sort: 4.08 seconds
# Number of Key Comparisons: 8191469
# Current Array Size: 900000
# Time Elapsed for Hybrid Sort: 4.56 seconds
# Number of Key Comparisons: 9220677
# Current Array Size: 1000000
# Time Elapsed for Hybrid Sort: 5.05 seconds
# Number of Key Comparisons: 10238369
# Current Array Size: 2000000
# Time Elapsed for Hybrid Sort: 10.63 seconds
# Number of Key Comparisons: 21477853
# Current Array Size: 3000000
# Time Elapsed for Hybrid Sort: 16.91 seconds
# Number of Key Comparisons: 33641663
# Current Array Size: 4000000
# Time Elapsed for Hybrid Sort: 22.31 seconds
# Number of Key Comparisons: 44951379
# Current Array Size: 5000000
# Time Elapsed for Hybrid Sort: 27.79 seconds
# Number of Key Comparisons: 56287622
# Current Array Size: 6000000
# Time Elapsed for Hybrid Sort: 35.87 seconds
# Number of Key Comparisons: 70277715
# Current Array Size: 7000000
# Time Elapsed for Hybrid Sort: 41.15 seconds
# Number of Key Comparisons: 82077172
# Current Array Size: 8000000
# Time Elapsed for Hybrid Sort: 46.83 seconds
# Number of Key Comparisons: 93908608
# Current Array Size: 9000000
# Time Elapsed for Hybrid Sort: 52.80 seconds
# Number of Key Comparisons: 105722329
# Current Array Size: 10000000
# Time Elapsed for Hybrid Sort: 229.44 seconds
# Number of Key Comparisons: 117574666

# %%
## Plot the Graph using Matplotlib
# Plot the Points
plt.plot(fixedThresholdXCoordinates, fixedThresholdYCoordinates)

# Naming the Axes
plt.xlabel("Input List Size N")
plt.ylabel("Number of Key Comparisons")
plt.title("Graph of number of Key Comparisons against different Input List Sizes N")
# Out:
# Text(0.5, 1.0, 'Graph of number of Key Comparisons against different Input List Sizes N')

# %% [markdown]
# #### Compare Empirical Results with Theoretical Analysis for Time Complexity

# %% [markdown]
# c)ii) With the value of N fixed, plot the number of key comparisons over different sizes of the threshold value S. Compare your empirical results with your theoretical analysis of the time complexity.

# %%
# Fix the Input Array Size
selectedArray = inputData[3]

# Create Arrays to store X and Y Coordinates
fixedArraySizeXCoordinates = []
fixedArraySizeYCoordinates = []

# Run Hybrid Sort after changing threshold value
numArrays = len(inputData)
thresholdValueS = 0
for i in range(numArrays):
    # Increment to change the thresholdValueS
    thresholdValueS += 10
    print("Current Threshold Value: {}".format(thresholdValueS))
    
    # Track the Time Elapsed for Hybrid Sort
    start = time.time()
    hybridSort(selectedArray, thresholdValueS, comparisonsObject)
    end = time.time()

    # Record the KeyComparisons (Y) and Different Threshold Values S(X)
    numKeyComparisons2 = comparisonsObject.returnKeyComparisons()
    fixedArraySizeXCoordinates.append(thresholdValueS)
    fixedArraySizeYCoordinates.append(numKeyComparisons2)
    
    # Show Time Elapsed & Num Key Comparisons
    print("Time Elapsed: {}".format(end - start))
    print("Number of Key Comparisons: {0:.2f} seconds".format(numKeyComparisons2))
    comparisonsObject.resetKeyComparisons()
# Out:
# Current Threshold Value: 10
# Time Elapsed: 0.0159759521484375
# Number of Key Comparisons: 25078.00 seconds
# Current Threshold Value: 20
# Time Elapsed: 0.010755062103271484
# Number of Key Comparisons: 23205.00 seconds
# Current Threshold Value: 30
# Time Elapsed: 0.010463953018188477
# Number of Key Comparisons: 23205.00 seconds
# Current Threshold Value: 40
# Time Elapsed: 0.009462118148803711
# Number of Key Comparisons: 21291.00 seconds
# Current Threshold Value: 50
# Time Elapsed: 0.009346961975097656
# Number of Key Comparisons: 21291.00 seconds
# Current Threshold Value: 60
# Time Elapsed: 0.009474039077758789
# Number of Key Comparisons: 21291.00 seconds
# Current Threshold Value: 70
# Time Elapsed: 0.008147954940795898
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 80
# Time Elapsed: 0.008177042007446289
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 90
# Time Elapsed: 0.008138895034790039
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 100
# Time Elapsed: 0.008210897445678711
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 110
# Time Elapsed: 0.008116960525512695
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 120
# Time Elapsed: 0.008228778839111328
# Number of Key Comparisons: 19302.00 seconds
# Current Threshold Value: 130
# Time Elapsed: 0.007217884063720703
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 140
# Time Elapsed: 0.00718998908996582
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 150
# Time Elapsed: 0.007261037826538086
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 160
# Time Elapsed: 0.006992816925048828
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 170
# Time Elapsed: 0.007003068923950195
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 180
# Time Elapsed: 0.0070917606353759766
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 190
# Time Elapsed: 0.0071218013763427734
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 200
# Time Elapsed: 0.006964206695556641
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 210
# Time Elapsed: 0.0070667266845703125
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 220
# Time Elapsed: 0.007063627243041992
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 230
# Time Elapsed: 0.006999015808105469
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 240
# Time Elapsed: 0.007091999053955078
# Number of Key Comparisons: 17335.00 seconds
# Current Threshold Value: 250
# Time Elapsed: 0.00603795051574707
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 260
# Time Elapsed: 0.0060579776763916016
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 270
# Time Elapsed: 0.0059659481048583984
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 280
# Time Elapsed: 0.005924701690673828
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 290
# Time Elapsed: 0.00588226318359375
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 300
# Time Elapsed: 0.0060520172119140625
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 310
# Time Elapsed: 0.006066322326660156
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 320
# Time Elapsed: 0.006014823913574219
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 330
# Time Elapsed: 0.005976676940917969
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 340
# Time Elapsed: 0.00598907470703125
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 350
# Time Elapsed: 0.0059661865234375
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 360
# Time Elapsed: 0.005961894989013672
# Number of Key Comparisons: 15348.00 seconds
# Current Threshold Value: 370
# Time Elapsed: 0.006024837493896484
# Number of Key Comparisons: 15348.00 seconds

# %%
## Plot the Graph
# Plot the Points
plt.plot(fixedArraySizeXCoordinates, fixedArraySizeYCoordinates)

# Naming the Axes
plt.xlabel("Threshold Values S")
plt.ylabel("Number of Key Comparisons")
plt.title("Graph of number of Key Comparisons over different Threshold Values S")
plt.show()
